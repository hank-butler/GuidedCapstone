# %% [markdown]
# # Guided Capstone Step 6. Documentation

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.  Modeling
#
# 6.   **Documentation**
#   * Review the Results
#   * Finalize Code
#   * Finalize Documentation
#   * Create a Project Report
#   * Create a Slide Deck for the Executive Audience

# %% [markdown]
# In this guided capstone we are going to revisit many of the actions we took in the previous guided capstone steps. This gives you the opportunity to practice the code you wrote to solve the questions in step 4 and 5.

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import explained_variance_score, mean_absolute_error

# %matplotlib inline

os.getcwd()
# Out:
# 'C:\\Users\\pam\\Desktop\\Hank\\springboard\\Springboard'

# %% [markdown]
# ## Fit Models with Training Dataset

# %% [markdown]
# **<font color='teal'> Using sklearn fit the model you chose in Guided Capstone 5 on your training dataset. This includes: creating dummy features for states if you need them, scaling the data,and creating train and test splits before fitting the chosen model.Also, remember to generate a model performance score(MAE, or explained variance) based on the testing hold-out data set.</font>**

# %% [markdown]
# #### Best Model

# %%
df = pd.read_csv('C:\\Users\\pam\\Desktop\\Hank\\springboard\\Springboard\\data\\step3_output.csv', index_col = 0)

# %%
df.shape
# Out:
# (330, 26)

# %%
df.head()
# Out:
#                   Name    state  summit_elev  vertical_drop  trams  fastEight  \
# 0       Alyeska Resort   Alaska         3939           2500      1        0.0
# 1  Eaglecrest Ski Area   Alaska         2600           1540      0        0.0
# 2     Hilltop Ski Area   Alaska         2090            294      0        0.0
# 3     Arizona Snowbowl  Arizona        11500           2300      0        0.0
# 4  Sunrise Park Resort  Arizona        11100           1800      0        0.0
#
#    fastSixes  fastQuads  quad  triple  ...  SkiableTerrain_ac  Snow Making_ac  \
# 0          0          2     2       0  ...             1610.0           113.0
# 1          0          0     0       0  ...              640.0            60.0
# 2          0          0     0       1  ...               30.0            30.0
# 3          1          0     2       2  ...              777.0           104.0
# 4          0          1     2       3  ...              800.0            80.0
#
#    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 0             150.0       60.0            669.0          65.0          85.0
# 1              45.0       44.0            350.0          47.0          53.0
# 2             150.0       36.0             69.0          30.0          34.0
# 3             122.0       81.0            260.0          89.0          89.0
# 4             115.0       49.0            250.0          74.0          78.0
#
#    projectedDaysOpen  NightSkiing_ac  clustes
# 0              150.0           550.0        0
# 1               90.0             0.0        0
# 2              152.0            30.0        0
# 3              122.0             0.0        1
# 4              104.0            80.0        1
#
# [5 rows x 26 columns]

# %%
# Drop unneeded features
x = df.drop(['Name', 'AdultWeekend', 'clustes', 'state', 'summit_elev'], axis = 1)
# What we're trying to target
y = df['AdultWeekend']

# %%
# Scaling
scaler = preprocessing.StandardScaler().fit(x)
x_scaled = scaler.transform(x)

# %%
# 1d array of response variable

y = y.ravel()

# generating train/test data

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.25, random_state = 1)

# %%
# Fit and score linear model

lm = LinearRegression()
model = lm.fit(x_train,y_train)
lm_score = model.score(x_test, y_test)
print(lm_score)
# Out:
# 0.9126834554818861

# %%
# Generating predictions

y_pred = model.predict(x_test)

# %%
# Explained Variance Score
explained_variance_score(y_test, y_pred)
# Out:
# 0.9132330867529284

# %%
# MAE
mean_absolute_error(y_test, y_pred)
# Out:
# 6.003201150968498

# %%
# Creating clusters

from sklearn.cluster import KMeans

x = df.drop(['Name', 'clustes', 'state'], axis= 1).values
kmeans = KMeans(n_clusters = 2)
y_kmeans = kmeans.fit_predict(x)
centers = kmeans.cluster_centers_

# %%
plt.scatter(x[:,0], x[:,1], c=y_kmeans, s=50, cmap='viridis')
plt.scatter(centers[:,0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
df['clusters'] = y_kmeans

# %% [markdown]
# ## Review the results

# %% [markdown]
# **<font color='teal'> Now, let's predict the Big Mountain Weekend price with our model in order to provide a recommendation to our managers on how to price the `AdultWeekend` lift ticket. First we need to find the row for Big Mountain resort in our data using string contains or string matching.</font>**

# %%
# Changed to Whitefish, not Big Mountain since Big Mountain isn't in there.

wf_df = df[df['Name'].str.contains('Whitefish')]
wf_df.head()
# Out:
#                           Name    state  summit_elev  vertical_drop  trams  \
# 151  Whitefish Mountain Resort  Montana         6817           2353      0
#
#      fastEight  fastSixes  fastQuads  quad  triple  ...  Snow Making_ac  \
# 151        0.0          0          3     2       6  ...           600.0
#
#      daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 151             123.0       72.0            333.0          81.0          81.0
#
#      projectedDaysOpen  NightSkiing_ac  clustes  clusters
# 151              123.0           600.0        1         0
#
# [1 rows x 27 columns]

# %% [markdown]
# **<font color='teal'> Prepare the Big Mountain resort data row as you did in the model fitting stage.</font>**

# %%
x = wf_df.drop(['Name', 'AdultWeekend', 'clusters', 'clustes', 'state', 'summit_elev'], axis=1)
x_scaled = scaler.transform(x)
x_scaled
# Out:
# array([[ 1.20196524, -0.30893969, -0.05513178, -0.2840776 ,  0.90289472,
#          0.81409101,  2.78349171, -1.01161941,  0.18418936,  0.99023179,
#          1.23873862,  0.76679853,  1.62949472,  1.25487649,  1.8017921 ,
#          0.24535374,  0.07820484,  1.10855403,  0.96733304,  0.10268497,
#          5.81966027]])

# %% [markdown]
# **<font color='teal'> Predict the Big Mountain resort `Adult Weekend` price and print it out.</font>** This is our expected price to present to management. Based on our model given the characteristics of the resort in comparison to other ski resorts and their unique characteristics.

# %%
pred_price = model.predict(x_scaled)
"${:.2f}".format(pred_price[0])
# Out:
# '$88.13'

# %% [markdown]
# **<font color='teal'> Print the Big Mountain resort actual `Adult Weekend` price.</font>**

# %%
# previous row

# %% [markdown]
# **<font color='teal'> As part of reviewing the results it is an important step to generate figures to visualize the data story. We can use the clusters we added to our data frame to create scatter plots for visualizing the Adult Weekend values compared to other characteristics. Run the example below to get you started and build two or three more figures to include in your data story telling.</font>**

# %%
# sample plot
plt.scatter(df['summit_elev'], df['vertical_drop'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(ac['summit_elev'], ac['vertical_drop'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
plt.savefig('figures/fig1.png',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-274e77a95fbc> in <module>
#       1 plt.scatter(df['summit_elev'], df['vertical_drop'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
# ----> 2 plt.scatter(ac['summit_elev'], ac['vertical_drop'], c='black', s=100)
#       3 plt.xlabel('summit_elev')
#       4 plt.ylabel('vertical_drop')
#       5 plt.title('summit_elev by vertical_drop by cluster')
#
# NameError: name 'ac' is not defined

# %%
plot_x = 'summit_elev'
plot_y = 'vertical_drop'
plt.scatter(df[plot_x], df[plot_y], c=df['clusters'], s=50, cmap='viridis', label='clusters')
plt.scatter(wf_df[plot_x], wf_df[plot_y], c='red', s=100)
plt.xlabel('Summit Elevation (ft)')
plt.ylabel('Vertical Drop (ft)')
plt.title('Cluster by Summit Elevation (ft) and Vertical Drop (ft)')
plt.savefig('figures/fig1.png', bbox_inches='tight')

# %%
plot_x = 'summit_elev'
plot_y = 'AdultWeekend'
plt.scatter(df[plot_x], df[plot_y], c=df['clusters'], s=50, cmap='viridis', label='clusters')
plt.scatter(wf_df[plot_x], wf_df[plot_y], c='red', s=100)
plt.xlabel('Summit Elevation (ft)')
plt.ylabel('Adult Weekend ($)')
plt.title('Cluster by Summit Elevation (ft) and Adult Weekend ($)')
plt.savefig('figures/fig2.png', bbox_inches='tight')

# %%
plot_x = 'summit_elev'
plot_y = 'AdultWeekday'
plt.scatter(df[plot_x], df[plot_y], c=df['clusters'], s=50, cmap='viridis', label='clusters')
plt.scatter(wf_df[plot_x], wf_df[plot_y], c='red', s=100)
plt.xlabel('Summit Elevation (ft)')
plt.ylabel('Adult Weekday ($)')
plt.title('Cluster by Summit Elevation (ft) and Adult Weekday ($)')
plt.savefig('figures/fig3.png', bbox_inches='tight')

# %% [markdown]
# ## Finalize Code

# %% [markdown]
#  Making sure our code is well organized and easy to follow is an important step. This is the time where you need to review the notebooks and Python scripts you've created and clean them up so they are easy to follow and succinct in nature. Addtionally, we will also save our final model as a callable object using Pickle for future use in a data pipeline. Pickle is a module that serializes (and de-serializes) Python objects so that they can become executable objects like functions. It's used extensively in production environments where machine learning models are deployed on an industrial scale!**<font color='teal'> Run the example code below to save out your callable model. Notice that we save it in the models folder we created in our previous guided capstone step.</font>**

# %%
import pickle
s = pickle.dumps(model)
from joblib import dump, load
dump(model, 'models/regression_model_adultweekend.joblib')
# Out:
# ['models/regression_model_adultweekend.joblib']

# %% [markdown]
# ## Finalize Documentation

# %% [markdown]
# For model documentation, we want to save the model performance metrics as well as the features included in the final model. You could also save the model perfomance metrics and coefficients fo the other models you tried in case you want to refer to them later. **<font color='teal'> Create a dataframe containing the coefficients and the model performance metrics and save it out as a csv file, then upload it to your github repository.</font>**

# %%
coef_df = pd.DataFrame(abs(model.coef_), x.columns, columns = ['Coefficient'])
coef_df.sort_values(by='Coefficient', ascending = False)
# Out:
#                    Coefficient
# AdultWeekday         20.704076
# averageSnowfall       2.456960
# quad                  1.634838
# triple                1.430568
# surface               1.152929
# daysOpenLastYear      0.616008
# TerrainParks          0.570448
# total_chairs          0.491202
# NightSkiing_ac        0.483606
# Runs                  0.448265
# vertical_drop         0.444609
# double                0.365659
# yearsOpen             0.358669
# SkiableTerrain_ac     0.269804
# trams                 0.269567
# fastSixes             0.210276
# fastQuads             0.178392
# Snow Making_ac        0.141438
# LongestRun_mi         0.125623
# fastEight             0.118245
# projectedDaysOpen     0.033663

# %%
coef_df.to_csv('./data/model_coef.csv')
